# %%
text = '''
6. io vedo un gatto. e una bambina. pòi delle api. tre api perche pòi ho detto due api. una montagna. 18. tanno mangiando. vedo una nonna. un bambino. delle uova. pòi vedo dei mobili. pòi dei mobili s^opra. 31. vedo un bambino che s^i fa la doccia.ha un giocattolo in mano. degli as^ciughimani. come s^i non mi ricordo. as^ciugamani. pòi vedo tanto tanto s^apone nella doccia. oppure acqua non lo s^o. pòi dei mobili qui. pòi vedo un bambino con un giocattolo. pòi vedo cambi della doccia. 15. qui vedo che s^tanno giocando dei bambini. al parco. dello s^ci. ci s^ono gli s^civoli. i bambini. le antalene. cos^’è quello. e quello che g^ira. non $o come s^i chiama. e pòi quel co$o che non s^o come s^i chiama. e pòi delle s^calette. 9. una dottores^s^a. un cuore s^paccato. una croce. un bambino. una. delle bottiglie. dei mobili qui. un bambino è malato. s^i vede perche ha il cerotto. due. pòi vedo un muro verde. tutto verde. pòi vedo un bambino. pòi vedo un cucchiaio. con s^opra lo s^ciroppo. pòi vedo un mobile. con delle bottiglie s^opra. 1. una pecorella. una bambina. e un trenino. pòi ci s^ono gli alberi. perche s^taranno facendo una pas^s^eggiata. e pòi un trenino che va s^ulle rotaie. pòi vedo una pecorella. gli s^ta dando il biberon. pòi degli alberi con s^opra una chioma. e pòi le foglie. 21. vedo un. un bambino piccolo. che s^ta giocando colla mamma. pòi vedo una fines^tra. un muro tutto verde tutto azzurro. pòi una fines^tra. una ca$etta. degli alberi. il cielo. il pavimento. il pavimento tutto marrone e bianco. pòi che s^tanno giocando. i lego. pòi vedo delle cos^e s^tane qui. la bambola. che non avevo letto. 17. ci s^ono delle api. che hanno punto a una pers^ona. la s^chiena. e es^ce del s^angue. pòi vedo un muro giallo s^curo. pòi la s^chiena tutta ro$a. 22. io vedo qua una pers^ona che s^ta bevendo il caffè. un piattino. pòi un giornale. un tavolo tutto. tutto marrone. pòi vedo una s^edia tutta blu. pòi una maglia tutta blu. una perts^ona. un muro tutto giallo. e bo. 39. vedo. inizio. allora. vedo un muro tutto giallo. un trenino. pòi tutto. pòi vedo. un pavimento tutto. come prima. che è tutto marrone. che tutte ques^te cos^e che. pòi una maglia. un bambino. pòi cos^a vedo. niente. non vedo niente. una s^edia e bas^ta. 20. una tromba. vedo un bambino che s^a giocando. al tamburo. pòi vedo delle mudichette. pòi vedo il divano. pòi vedo un bambino e una mamma. un muro tutto giallo. il pavimento con le s^tris^ce e pòi tutto colorato di blu. pòi vedo una mudichetta qui. 2. io vedo delle s^elle. una fines^tra. un muro tutto blu. una tenda tutta ro$a. pòi un mobile tutto blu. s^a dommendo un bambino. qui c’è una s^catoletta s^otto il letto. 5. allora. una rana che gli occhiali. pòi una foglia. un’altra foglia. un pes^ce. dei fiorellini ancora foglie foglie foglie. pòi dei fiorellini fiorellini. pòi s^econdo me ques^ta rana s^i butta anche in mare. 42. io vedo una macchina. una pers^ona che s^ta aggius^tado un motore di una macchina. pòi vedo le gomme. le s^carpe. il cielo tutto azzurro. e pòi vedo la s^abbia. 24. allora io vedo una. una ragazza che s^a nuotando. s^ott’acqua. con i pes^ci. una tartaruga. e delle alghe. dei pes^ci. delle foglie. delle alghe. e pòi le bollicine. 27. uu è natale. io vedo un albero. vedo un albero s^opra una s^tella. pòi vedo un pavimento tutto con le s^tris^ce bianche e marrone. pòi vedo una tigre. pòi vedo una bambina che è felice. pòi vedo una mamma che s^orride. e pòi vedo dei fiori. delle palline. natale. pòi vedo il muro tutto giallo. non lo s^o. 29. vedo un camion. una s^cimmia. una macchinina. un gioco da bambini piccoli. s^a giocando un bambino. 41. s^anno giocando a uno due tre s^ella. pòichè vedo degli alberi. delle foglie. foglie. pòi vedo una foglia con gli occhi. e qua c’è un bambino che è nas^cos^to s^otto le foglie. pòi vedo una bambina lì. e pòi vedo un bambino non s^o s^e è un bambino che s^ta guardando. pòi c’è tutto il giorno. e il s^ole. 23. io vedo che i bambini s^ta dando un bacio ad una ragazza. pòi vedo una matita. un foglio. un as^tuccio. e un muro tutto azzurro. una mela. una matita. un libro. e pòi vedo ques^ti due bambini. 36. allora ci s^ono degli alberi. delle nuvole. pòi c’è il cielo tutt’azzurro. dei fiorellini. delle farfalline. pòi vedo una bambina. con una farfalla s^ul nas^o. pòi vedo un fiore che in mano una bambina. gli alberi. 8. allora io vedo. l’abbiamo già fatta prima. s^i fa la doccia. pòi vedo un muro tutto viola con le s^tris^ce a quadrati bianchi. viola dentro. pòi il s^apone. le bollicine. l’acqua. il s^apone. e pòi non s^o. e la s^pugna. 30. elefante. vedo degli alberi. un elefante. pòi delle ciliegie. pòi un des^erto. pòi vedo delle foglie. un ramo. la chioma. che non c’è. delle foglie. un’altra foglia. il cielo azzurro. delle nuvole. pòi vedo i corni. un elefanta s^a mangiando. perche l’elefante non hanno la bocca. a s^i ce l’ha. 35. oddio. vedo una s^ignora. un fazzoletto. e un muro tutto azzurro. perche una nonna è malata. 32. oddio. ques^ta s^arà la mia figura preferita. allora il cielo è azzurro. azzurro con le nuvole. pòi vedop un camion. una s^irena. pòi vedo una pers^ona. una moto il fumo. del fuoco. dell’acqua. perche fors^e ques^ta moto ha pres^o fuoco. ha bocciato. uomo. s^econdo me. è s^ucces^s^o che ha bocciato una moto. e ades^s^o s^ono venuti i pompieri. 7. ques^ta è anche la mia preferita. il tramonto. pòi vedo un coniglietto che s^a mangiando carote che a me non piacciono. pòi un cavallo che s^a mangiando l’ins^alata. pòi vedo una s^alla. il tramonto. dei rami la chioma le foglie. uguale. qui un alberello piccolo. pòi delle foglie. un cavallo. un coniglietto. una porta. delle fines^trine. pòi un tetto bianco. pòi vedo delle foglie. pòi una foglia s^ulla carota. 26. i:o vedo una pèra. un muro tutto giallo. quello è un ragno. ques^s^o marrone. è s^olo ròtta. pòi vedo il formaggio. pòi vedo il tavolo tutto. a me il tavolo mi s^èmbra. oppure più bas^s^o. topra al tavolo pòi vedo le strisce come prima e pòi vedo un tòpo. quindi mi sa che un tòpo è entrato dentro ca$^a di una perz^ona. 11. vedo um bambino che s^a mangiando un gelato. pòi vedo il verde. il giallo. il ros^s^o. ma è all’incontrario. è all’incontrario. pòi delle co$^e dalle s^risce. pòi vedo una torre. dei fiorellini. delle fòie. pòi vedo um bambino piccolo. una perzòna. un gelato. vedo un bambino con il gelato. il cièlo tutto az^z^urro e un s^òle. s^anno facèndo una pas^s^eggiata. e il bambino as^petta la mamma. 28. vedo il cielo tutto az^z^urro. un albero. la chiòma. dentro le fòglie. pòi un altra fòglia. un nònno. il bas^s^one che lancia. il nònno lancia un bel bas^s^oncino al cane. pòi delle fòglie. qua <la la come si chiama> l’èrba. 13. s^anno facendo una pas^s^eggiata oppure il nònno prima lancia il co$^o al cane e pòi s^e ne va vi:a. 19. vedo il cièlo tutto az^z^urro. dei pomodòri. un uccellino. una bambina che s^a paz^z^olando il cavallo o il pòni. non s^ò. pòi vedo una gallina che s^a fascendo le uòva. pòi vedo degli alberi. delle ro$^e. e pòi <una una> non sò. una montagnètta. 38. un ippopòtamo. una z^èbra. una giraffa. pòi vedo una pòrta. ò ò z^. z^ò. (è la prima vòlta che lèggo. s^ò ancora imparando. perche mi:a madre ogni vòlta mi dice vuòi xxx. nò. giòco s^olo ai videogiòchi.) pòi vedo l’èrbètta. pòi vedo non capis^co. la z^èbra s^a lanciando ques^s^’acqua. ma pòs^s^ono scavalcare. la giraffa nò. non può scavalcare. pòi vedo un cancèllo. delle maniglie. 34. l’èrba. pòi vedo un bambino. una dònna. una mamma. pòi vedo degli alberi. la chiòma uguale. e pòi vedo un bambino che s^a piangèndo perche gli è volato via il palloncino. 4. vedo delle macchinine. pòi vedo una bambina. un bambino. pòi vedo una scimmia. una scimmietta. pòi vedo il muro tutto giallo e bas^s^a. allòra vedo un muro tutto col^orato. pòi vedo una bambina più alta. una bambina più piccola. un bambino più piccolo. pòi vedo una tòrta perche s^arà il compleanno. e le candeline s^opra il fuòco. pòi vedo un tavolo. un tavolo. e pòi vedo ques^se co$^e qui. un compleanno. 33. cade. cade. non s^o. il vèntro. con dentro l’acqua. pòi vedo la bambina che s^i mette le mani co$ì. s^a piangèndo perché <perché il il vre> il vetro è caduto è uscita tutta l’acqua e pòi il palloncino non s^ò co$a ci fa lì. 25. ma s^ono i un bar o una ca$a. un bar. nò una ca$^a. i:o vedo un uòmo. pòi vedo una finès^ra. <pòi vedo il pòi vedo il. come s^i dice già. non mi ricòrdo. non mi ricòrdo.>. vedo una spaz^z^ola. come s^i chiama. fiòri. e ques^s^a come s^i chiama già. qua vedo delle s^carpètte. pòi vedo una maietta. un papa. vedo una bambina. una finès^s^ra. e vedo un ves^s^itino e pòi vedo il pavimento tutto come prima. con le strisce nere. pòi con ques^s^e co$^e qui. e pòi marrone. 40. vedo una mamma. una s^paz^z^ola. vedo un gufo. um bambino. perche la mamma s^a s^cacciando via il gufo. pòi vedo un tappeto. 10. (ques^s^a mi fa venire fame.) vedo un vino ros^s^o. l’acqua. un panino. la piz^z^a. e s^ono andati a un ris^s^orante. pòi un cuscino s^otto. 14. vedo delle fòrbici. delle caramèlle. una bambina che s^a. (sì lo so ma non mi ricordo. come gli attori.) pingèndo. pòi vedo um bambino. vedo una ragaz^z^a. pòi vedo co$^e e pòi bas^s^a. 37. (però il bambino mi fa ridere con quel s^orri$^o.) vedo delle ligne bianche. pòi dentro giallo. pòi vedo um bambino con gli occhiali. e un dolcino. pòi vedo il caffè. pòi dell’acqua. pòi un nònno e pòi um bambino. s^anno facendo merènda. 12. vedo dei fiorellini. una chiòma. pòi vedo delle fòglie. pòi vedo una bici. una bambina sopra la bici. una barchètta di lègno. pòi vedo quès^s^o. pòi vedo la bambina che s^a s^alutando la s^u:a amica. vedò un fiorellino lì. l’uccèllo e le nuvole. 16. qui s^a nevicando. pòi vedo delle pèrle. non s^ò. vedo un pinguino con um bambino. vedo il cièlo az^z^urro. vedo le alberi. come fanno cinque e cinque più cinque fa vènti s^e mi ricòrdo. pòi vedo un bambino che li còppie pinguino. pinguino. 3.  vedo un rubinetto. l’acqua. pòi vedo dentifricio. pòi vedo un asciugamano. un lègno. pòi vedo lo spaz^z^olino. pòi vedo pigiama. s^i s^a lavando i dènti perche s^a andando a lètto.    

'''

# %%
import re

def funct_convertitoreIPA(testo_da_convertire):


    regex_parentesi = r"\<(.*?)\>|\((.*?)\)"  # provo ad eliminare dalla conversione il trascritto dell'adulto tra parentesi tonde e angolari

    if re.search(regex_parentesi, testo_da_convertire):
        testo_da_convertire = re.sub(regex_parentesi, "", testo_da_convertire)



    # VOCALI
    testo_da_convertire = testo_da_convertire.lower()
    testo_da_convertire = re.sub(r'\d+.', '', testo_da_convertire) # eliminazione di tutti i numeri più spazio
    testo_da_convertire = re.sub("c'ha", "ʧa", testo_da_convertire)
    testo_da_convertire = re.sub('\s\s+', ' ', testo_da_convertire) # rimozioni tripli e + spazi

    testo_da_convertire = testo_da_convertire.replace("’", "'")
    testo_da_convertire = testo_da_convertire.replace("un'", "un' ")
    testo_da_convertire = testo_da_convertire.replace("l'", "l' ")
    testo_da_convertire = testo_da_convertire.replace("'", "")


    testo_da_convertire = testo_da_convertire.replace("ò", "ɔ")
    testo_da_convertire = testo_da_convertire.replace("è", "ɛ")
    testo_da_convertire = testo_da_convertire.replace("ù", "u")
    testo_da_convertire = testo_da_convertire.replace("à", "a")
    testo_da_convertire = re.sub("peluche", "peluʃ", testo_da_convertire)
    testo_da_convertire = re.sub("fat:orja", "fat:o:ri:a", testo_da_convertire)
    testo_da_convertire = re.sub("hamburger", "amburger", testo_da_convertire)
    testo_da_convertire = re.sub(" jo", " i:o", testo_da_convertire)

    # GEMINATE
    testo_da_convertire = testo_da_convertire.replace("bb", "b:")
    testo_da_convertire = testo_da_convertire.replace("cce", "t:ʃe")
    testo_da_convertire = testo_da_convertire.replace("ccɛ", "t:ʃɛ")
    testo_da_convertire = testo_da_convertire.replace("gge", "d:ʒe")
    testo_da_convertire = testo_da_convertire.replace("ggɛ", "d:ʒɛ")
    testo_da_convertire = testo_da_convertire.replace("q", "c")

    # Allofoni
    testo_da_convertire = testo_da_convertire.replace("s[", "θ")
    testo_da_convertire = testo_da_convertire.replace("r[", "ʀ")

    testo_da_convertire = testo_da_convertire.replace(" /", "/")

    # cambio della precedente regola delle distorsioni con il simbolo dell'articolazione debole
    simbolo_articolazione_debole = chr(841)
    testo_da_convertire = testo_da_convertire.replace("^", simbolo_articolazione_debole)

    lista_fonemi = ["c", "g"]

    for fonema_target in lista_fonemi:
        rx = f"({fonema_target}{fonema_target})(i)([aeɛoɔu])"

        # parole come cacciavite aggiustare
        if fonema_target == "c":
            testo_da_convertire = re.sub(rx, r"t:ʃ\3", testo_da_convertire)
        elif fonema_target == 'g':
            testo_da_convertire = re.sub(rx, r"d:ʒ\3", testo_da_convertire)

        # esempi: pecche, pecca, , accordare, accòllo, accudire

        # Provo ad utilizzare un capturing group, per poi modificare solo questo e non la vocale
        rx = f"({fonema_target}{fonema_target})([haoɔu])"

        # Utilizzando $2 viene lasciato invariato il secondo gruppo, quindi le vocali
        if fonema_target == "c":
            testo_da_convertire = re.sub(rx, r"k:\2", testo_da_convertire)
        elif fonema_target == 'g':
            testo_da_convertire = re.sub(rx, r"g:\2", testo_da_convertire)
        



    for fonema_target in lista_fonemi:
        rx1 = f'({fonema_target})([haoɔu])'
        if fonema_target == 'c':
            testo_da_convertire = re.sub(rx1, r'k\2', testo_da_convertire)
        elif fonema_target == 'g':
            testo_da_convertire = re.sub(rx1, r'g\2', testo_da_convertire)

        rx1 = '([^s])(ci)([eɛaoɔu])'
        testo_da_convertire = re.sub(rx1, r'\1ʧ\3', testo_da_convertire)

        rx1 = '(c)(i)([haoɔu])'
        testo_da_convertire = re.sub(rx1, r'ʧ\3', testo_da_convertire)

        rx1 = '(g)(i)([haoɔu])'
        testo_da_convertire = re.sub(rx1, r'ʤ\3', testo_da_convertire)

        # rx1 = '(g)([ieɛ])'
        # testo_da_convertire = re.sub(rx1, r'ʤ\2', testo_da_convertire)

        rx1 = '(c)([^imeɛaoɔu])'
        testo_da_convertire = re.sub(rx1, r'k\2', testo_da_convertire)

        #_____________________________________________________________
        #REGOLE MANUALI DA MANTENERE
        testo_da_convertire = testo_da_convertire.replace('ci', 'ʧi')
        testo_da_convertire = testo_da_convertire.replace('ce', 'ʧe')
        testo_da_convertire = testo_da_convertire.replace('cɛ', 'ʧɛ')
        testo_da_convertire = testo_da_convertire.replace("c'e", "ʧe")
        testo_da_convertire = testo_da_convertire.replace("c'ɛ", "ʧɛ")

        #testo_da_convertire = testo_da_convertire.replace("gi", "ʤi")
        #testo_da_convertire = testo_da_convertire.replace("ge", "ʤe")
        #testo_da_convertire = testo_da_convertire.replace("gɛ", "ʤɛ")

        testo_da_convertire = testo_da_convertire.replace("sʧe", "ʃe")
        testo_da_convertire = testo_da_convertire.replace("sʧɛ", "ʃɛ")
        testo_da_convertire = testo_da_convertire.replace("sʧi", "ʃi")
        testo_da_convertire = testo_da_convertire.replace("sʧa", "ʃa")
        testo_da_convertire = testo_da_convertire.replace("sʧe", "ʃe")
        testo_da_convertire = testo_da_convertire.replace("sʧo", "ʃo")
        testo_da_convertire = testo_da_convertire.replace("sʧu", "ʃu")
        testo_da_convertire = testo_da_convertire.replace("sʧɛ", "ʃɛ")
        testo_da_convertire = testo_da_convertire.replace("sʧɔ", "ʃɔ")

        #_____________________________________________________________

        testo_da_convertire = testo_da_convertire.replace("dd", "d:")
        testo_da_convertire = testo_da_convertire.replace("ff", "f:")
        testo_da_convertire = testo_da_convertire.replace("gg", "g:")
        testo_da_convertire = testo_da_convertire.replace("ll", "l:")
        testo_da_convertire = testo_da_convertire.replace("mm", "m:")
        testo_da_convertire = testo_da_convertire.replace("nn", "n:")
        testo_da_convertire = testo_da_convertire.replace("pp", "p:")
        testo_da_convertire = testo_da_convertire.replace("rr", "r:")
        testo_da_convertire = testo_da_convertire.replace("ss", "s:")
        testo_da_convertire = testo_da_convertire.replace("tt", "t:")
        testo_da_convertire = testo_da_convertire.replace("vv", "v:")

        # testo_da_convertire = testo_da_convertire.replace("sc", "ʃ")
        rx1 = "([s])(ci)([eɛaoɔu])"
        testo_da_convertire = re.sub(rx1, r"ʃ\3", testo_da_convertire)

        rx1 = "([s])(c)([eɛ])"
        testo_da_convertire = re.sub(rx1, r"ʃ\3", testo_da_convertire)

        testo_da_convertire = testo_da_convertire.replace("zz", "ʦ")
        testo_da_convertire = testo_da_convertire.replace("z", "ʣ")
        testo_da_convertire = testo_da_convertire.replace("ì", "i")

        # NASALI
        # testo_da_convertire = testo_da_convertire.replace("nf", "ɱf")
        # testo_da_convertire = testo_da_convertire.replace("nf", "ɱv")
        # testo_da_convertire = testo_da_convertire.replace("mf", "ɱf")
        # testo_da_convertire = testo_da_convertire.replace("mv", "ɱv")
        testo_da_convertire = testo_da_convertire.replace("gn", "ɲ")
        testo_da_convertire = re.sub("gli ", "ʎi ", testo_da_convertire)
        testo_da_convertire = testo_da_convertire.replace("gli", "ʎ")


        # DITTONGHI E SEMIVOCALI
        testo_da_convertire = testo_da_convertire.replace("ia", "ja")
        testo_da_convertire = testo_da_convertire.replace("ie", "je")
        testo_da_convertire = testo_da_convertire.replace("iu", "ju")
        testo_da_convertire = testo_da_convertire.replace("ia", "ja")
        testo_da_convertire = testo_da_convertire.replace("io", "jo")

        testo_da_convertire = testo_da_convertire.replace("ua", "wa")
        testo_da_convertire = testo_da_convertire.replace("uo", "wo")
        testo_da_convertire = testo_da_convertire.replace("uɔ", "wɔ")
        testo_da_convertire = testo_da_convertire.replace("ue", "we")
        testo_da_convertire = testo_da_convertire.replace("uè", "wɛ")
        testo_da_convertire = testo_da_convertire.replace("ui", "wi")

        # CORREZIONI
        testo_da_convertire = testo_da_convertire.replace("ʃja", "ʃa")
        testo_da_convertire = testo_da_convertire.replace("ʃje", "ʃe")
        testo_da_convertire = testo_da_convertire.replace("ʃjo", "ʃo")
        testo_da_convertire = testo_da_convertire.replace("ʃju", "ʃu")

        testo_da_convertire = testo_da_convertire.replace("nʣj", "nʦj")
        testo_da_convertire = testo_da_convertire.replace("dʣi:", "ʣi:")

        # ECCEZIONI
        testo_da_convertire = testo_da_convertire.replace("anʣi", "anʦi")
        testo_da_convertire = testo_da_convertire.replace("anʣi", "anʦi")
        testo_da_convertire = testo_da_convertire.replace("lʣ", "lʦ")
        testo_da_convertire = testo_da_convertire.replace("aʣj", "aʦj")
        testo_da_convertire = testo_da_convertire.replace("ʤje", "ʤe")

        testo_da_convertire = testo_da_convertire.replace("ns", "nʦ")

        testo_da_convertire = testo_da_convertire.replace("d:ʒj", "d:ʒ")
        # testo_da_convertire = testo_da_convertire.replace("nc", "nk")

        testo_da_convertire = testo_da_convertire.replace(" ʣja ", " ʣi:a ")
        testo_da_convertire = testo_da_convertire.replace(" ʣjo ", " ʣi:o ")
        testo_da_convertire = testo_da_convertire.replace(" mja ", " mi:a ")
        testo_da_convertire = testo_da_convertire.replace(" twa ", " tu:a ")
        testo_da_convertire = testo_da_convertire.replace(" swa ", " su:a ")
        testo_da_convertire = testo_da_convertire.replace(" swo ", " su:o ")
        testo_da_convertire = testo_da_convertire.replace(" dwe ", " du:e ")
        testo_da_convertire = testo_da_convertire.replace(" lwi ", " lu:i ")

        testo_da_convertire = testo_da_convertire.replace("tS", "ʧ")
        testo_da_convertire = testo_da_convertire.replace("dG", "ʤ")
        testo_da_convertire = testo_da_convertire.replace("h", "")

        testo_da_convertire = testo_da_convertire.replace("'", "") # prima ELIMINATO PER CONSENTIRE LA SEGNALAZIONE DEGLI ACCENTI
        testo_da_convertire = testo_da_convertire.replace(",", "/")
        testo_da_convertire = testo_da_convertire.replace(".", "/")
        testo_da_convertire = testo_da_convertire.replace(" jo ", " io ")

        #Geminate intrinseche: i fonemi /ʃ/, /ɲ/, /ʎ/, /ʦ/ e /ʣ/ in posizione intervocalica e /ʦ/ tra una vocale e una semiconsonante
        #sono sempre realizzati concretamente come geminati.

        lista_fonemi = ["ʃ", "ɲ", "ʎ"]

        for fonema_target in lista_fonemi:
            rx = f'([aeɛijwoɔu]){fonema_target}([aeɛijwoɔu])'
            if fonema_target not in ["ʦ", "ʣ"]:
                testo_da_convertire = re.sub(rx, r'\1' + f'{fonema_target}' + r':\2', testo_da_convertire)

        fonemi_affr = ["ʦ", "ʣ"]

        for fonema_target in fonemi_affr:
            rx = f'([aeɛijwoɔu]){fonema_target}([aeɛijwoɔu])'
            if fonema_target == "ʦ":
                testo_da_convertire = re.sub(rx, r'\1t:s\2', testo_da_convertire)
            elif fonema_target == "ʣ":
                testo_da_convertire = re.sub(rx, r'\1d:z\2', testo_da_convertire)
        

        testo_da_convertire = testo_da_convertire.replace("ʧ", "ʧ")
        testo_da_convertire = testo_da_convertire.replace("dg", "ʤ")
        testo_da_convertire = testo_da_convertire.replace("ʣ", "ʣ")
        testo_da_convertire = testo_da_convertire.replace("ʦ", "ʦ")
        testo_da_convertire = testo_da_convertire.replace("à", "a")
        testo_da_convertire = testo_da_convertire.replace("à", "a")
        testo_da_convertire = testo_da_convertire.replace("ò", "o")
        testo_da_convertire = testo_da_convertire.replace("è", "e")
        testo_da_convertire = testo_da_convertire.replace("é", "e")
        testo_da_convertire = testo_da_convertire.replace("ì", "i")
        testo_da_convertire = testo_da_convertire.replace("ts", "ʦ")

    testo_da_convertire = testo_da_convertire.replace("$", "z")


    return testo_da_convertire
print(funct_convertitoreIPA(text))
# Out:
#  io vedo un gat:o/ e una bambina/ pɔi del:e api/ tre api perke pɔi o det:o du:e api/ una montaɲ:a/ tan:o manʤando/ vedo una non:a/ un bambino/ del:e wova/ pɔi vedo dei mobili/ pɔi dei mobili s͉opra/ vedo un bambino ke s͉i fa la dot:ʃa/a un ʤokat:olo in mano/ deʎ:i as͉ʧugimani/ kome s͉i non mi rikordo/ as͉ʧugamani/ pɔi vedo tanto tanto s͉apone nel:a dot:ʃa/ op:ure ak:wa non lo s͉o/ pɔi dei mobili kwi/ pɔi vedo un bambino kon un ʤokat:olo/ pɔi vedo kambi del:a dot:ʃa/ kwi vedo ke s͉tan:o ʤokando dei bambini/ al parko/ del:o s͉ʧi/ ʧi s͉ono ʎi s͉ʧivoli/ i bambini/ le antalene/ kos͉ɛ kwel:o/ e kwel:o ke g͉ira/ non zo kome s͉i kjama/ e pɔi kwel kozo ke non s͉o kome s͉i kjama/ e pɔi del:e s͉kalet:e/ una dot:ores͉s͉a/ un kwore s͉pak:ato/ una kroʧe/ un bambino/ una/ del:e bot:iʎ:e/ dei mobili kwi/ un bambino ɛ malato/ s͉i vede perke a il ʧerot:o/ dwe/ pɔi vedo un muro verde/ tut:o verde/ pɔi vedo un bambino/ pɔi vedo un kuk:jajo/ kon s͉opra lo s͉ʧirop:o/ pɔi vedo un mobile/ kon del:e bot:iʎ:e
# ...
